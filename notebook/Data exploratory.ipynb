# %% [markdown]
# # Data exploratory

# %%
import pandas as pd
import numpy as np

# %%
df_client = pd.read_csv('../data/cliente_tabla.csv')
df_client.head()
# Out:
#    Cliente_ID                            NombreCliente
# 0           0                               SIN NOMBRE
# 1           1                         OXXO XINANTECATL
# 2           2                               SIN NOMBRE
# 3           3                                EL MORENO
# 4           4  SDN SER  DE ALIM  CUERPO SA CIA  DE INT

# %%
df_prod = pd.read_csv('../data/producto_tabla.csv')
df_prod.head()
# Out:
#    Producto_ID                          NombreProducto
# 0            0                       NO IDENTIFICADO 0
# 1            9               Capuccino Moka 750g NES 9
# 2           41  Bimbollos Ext sAjonjoli 6p 480g BIM 41
# 3           53          Burritos Sincro 170g CU LON 53
# 4           72     Div Tira Mini Doradita 4p 45g TR 72

# %%
df_prod[df_prod.NombreProducto.str.contains('Burritos Sincro')]
# Out:
#       Producto_ID                      NombreProducto
# 3              53      Burritos Sincro 170g CU LON 53
# 1808        37086  Burritos Sincro 170g MTA LON 37086

# %%
df_town = pd.read_csv('../data/town_state.csv')
df_town.head()
# Out:
#    Agencia_ID                   Town             State
# 0        1110     2008 AG. LAGO FILT      MÉXICO, D.F.
# 1        1111  2002 AG. AZCAPOTZALCO      MÉXICO, D.F.
# 2        1112    2004 AG. CUAUTITLAN  ESTADO DE MÉXICO
# 3        1113     2008 AG. LAGO FILT      MÉXICO, D.F.
# 4        1114   2029 AG.IZTAPALAPA 2      MÉXICO, D.F.

# %% [markdown]
# ## Training set

# %%
df_train = pd.read_csv('../data/train.csv')
print(df_train.info())
df_train.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74180464 entries, 0 to 74180463
# Data columns (total 11 columns):
# Semana               int64
# Agencia_ID           int64
# Canal_ID             int64
# Ruta_SAK             int64
# Cliente_ID           int64
# Producto_ID          int64
# Venta_uni_hoy        int64
# Venta_hoy            float64
# Dev_uni_proxima      int64
# Dev_proxima          float64
# Demanda_uni_equil    int64
# dtypes: float64(2), int64(9)
# memory usage: 6.1 GB
# None
#    Semana  Agencia_ID  Canal_ID  Ruta_SAK  Cliente_ID  Producto_ID  \
# 0       3        1110         7      3301       15766         1212
# 1       3        1110         7      3301       15766         1216
# 2       3        1110         7      3301       15766         1238
# 3       3        1110         7      3301       15766         1240
# 4       3        1110         7      3301       15766         1242
#
# ...

# %%
product_count = len(df_train['Producto_ID'].unique())
print('There are %d products.' % product_count)
# Out:
# There are 1799 products.

# %%
client_count = len(df_train['Cliente_ID'].unique())
print('There are %d clients.' % client_count)
# Out:
# There are 880604 clients.

# %%
PRODUCT_ID = 2233
median = df_train[df_train.Producto_ID == PRODUCT_ID]['Demanda_uni_equil'].median()
print('Product median= %d' % median)
df_train[(df_train.Cliente_ID == 50379) & (df_train.Producto_ID == PRODUCT_ID)]
# Out:
# Product median= 3
#           Semana  Agencia_ID  Canal_ID  Ruta_SAK  Cliente_ID  Producto_ID  \
# 30             3        1110         7      3301       50379         2233
# 11165245       4        1110         7      3301       50379         2233
# 22174832       5        1110         7      3301       50379         2233
# 32790223       6        1110         7      3301       50379         2233
# 42982064       7        1110         7      3301       50379         2233
# 53364914       8        1110         7      3301       50379         2233
# 63771782       9        1110         7      3301       50379         2233
#
#           Venta_uni_hoy  Venta_hoy  Dev_uni_proxima  Dev_proxima  \
# 30                   38     757.72                0          0.0
# 11165245             32     638.08                0          0.0
# 22174832             40     797.60                0          0.0
# 32790223             44     877.36                0          0.0
# ...

# %%
PRODUCT_ID = 2233
median = df_train[df_train.Producto_ID == PRODUCT_ID]['Demanda_uni_equil'].median()
print('Product median= %d' % median)
df_train[(df_train.Cliente_ID == 24695) & (df_train.Producto_ID == PRODUCT_ID)]
# Out:
# Product median= 3
#           Semana  Agencia_ID  Canal_ID  Ruta_SAK  Cliente_ID  Producto_ID  \
# 28             3        1110         7      3301       24695         2233
# 11165243       4        1110         7      3301       24695         2233
# 22174830       5        1110         7      3301       24695         2233
# 32790221       6        1110         7      3301       24695         2233
# 42982062       7        1110         7      3301       24695         2233
# 53364912       8        1110         7      3301       24695         2233
# 63771779       9        1110         7      3301       24695         2233
#
#           Venta_uni_hoy  Venta_hoy  Dev_uni_proxima  Dev_proxima  \
# 28                    8     159.52                0          0.0
# 11165243             10     199.40                0          0.0
# 22174830              6     119.64                0          0.0
# 32790221              5      99.70                0          0.0
# ...

# %%
df_train[df_train.Producto_ID == PRODUCT_ID]
# Out:
#           Semana  Agencia_ID  Canal_ID  Ruta_SAK  Cliente_ID  Producto_ID  \
# 25             3        1110         7      3301       24080         2233
# 28             3        1110         7      3301       24695         2233
# 30             3        1110         7      3301       50379         2233
# 75             3        1110         7      3301      108104         2233
# 89             3        1110         7      3301      181232         2233
# 113            3        1110         7      3301      319641         2233
# 119            3        1110         7      3301      319974         2233
# 123            3        1110         7      3301      325070         2233
# 126            3        1110         7      3301      818913         2233
# 133            3        1110         7      3301      819816         2233
# 138            3        1110         7      3301      819832         2233
# 144            3        1110         7      3301      853124         2233
# ...

# %% [markdown]
# ## Test set

# %%
df_test = pd.read_csv('../data/test.csv')
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6999251 entries, 0 to 6999250
# Data columns (total 7 columns):
# id             int64
# Semana         int64
# Agencia_ID     int64
# Canal_ID       int64
# Ruta_SAK       int64
# Cliente_ID     int64
# Producto_ID    int64
# dtypes: int64(7)
# memory usage: 373.8 MB

# %%
print('Semana=%s' % df_test['Semana'].unique())
# Out:
# Semana=[11 10]

# %% [markdown]
# ## Submission

# %%
df_sub = pd.read_csv('../data/sample_submission.csv')
df_sub.head()
# Out:
#    id  Demanda_uni_equil
# 0   0                  7
# 1   1                  7
# 2   2                  7
# 3   3                  7
# 4   4                  7

# %%
df_train['Demanda_uni_equil'].median()
# Out:
# 3.0
